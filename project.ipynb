# %% [markdown]
# # Project

# %%
# !pip install torch torchvision matplotlib datasets transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 20.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 93.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 36.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 16.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 90.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 32.8 MB/s eta 0:00:00
# ...

# %%
us_states = ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 
             'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 
             'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 
             'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 
             'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 
             'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 
             'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 
             'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 
             'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']

# %%
id2label = {id:label for id,label in enumerate(us_states)}
label2id = {label:id for id,label in id2label.items()}

print(id2label)
print(label2id)
# Out:
# {0: 'Alabama', 1: 'Alaska', 2: 'Arizona', 3: 'Arkansas', 4: 'California', 5: 'Colorado', 6: 'Connecticut', 7: 'Delaware', 8: 'Florida', 9: 'Georgia', 10: 'Hawaii', 11: 'Idaho', 12: 'Illinois', 13: 'Indiana', 14: 'Iowa', 15: 'Kansas', 16: 'Kentucky', 17: 'Louisiana', 18: 'Maine', 19: 'Maryland', 20: 'Massachusetts', 21: 'Michigan', 22: 'Minnesota', 23: 'Mississippi', 24: 'Missouri', 25: 'Montana', 26: 'Nebraska', 27: 'Nevada', 28: 'New Hampshire', 29: 'New Jersey', 30: 'New Mexico', 31: 'New York', 32: 'North Carolina', 33: 'North Dakota', 34: 'Ohio', 35: 'Oklahoma', 36: 'Oregon', 37: 'Pennsylvania', 38: 'Rhode Island', 39: 'South Carolina', 40: 'South Dakota', 41: 'Tennessee', 42: 'Texas', 43: 'Utah', 44: 'Vermont', 45: 'Virginia', 46: 'Washington', 47: 'West Virginia', 48: 'Wisconsin', 49: 'Wyoming'}
# ...

# %% [markdown]
# ## Load training dataset

# %%
# !git clone https://huggingface.co/datasets/Rui6188/50States10K
# Out:
# Cloning into '50States10K'...
# remote: Enumerating objects: 500082, done.
# remote: Counting objects: 100% (500082/500082), done.
# remote: Compressing objects: 100% (500074/500074), done.
# remote: Total 500082 (delta 13), reused 500066 (delta 6), pack-reused 0
# Receiving objects: 100% (500082/500082), 70.94 MiB | 17.53 MiB/s, done.
# Resolving deltas: 100% (13/13), done.
# Updating files: 100% (500003/500003), done.

# %%
# if repo already exists, error thrown
# %cd ./50States10K
# !git pull --force
# %cd ..
# Out:
# /content/50States10K
# Already up to date.
# /content

# %%
import transformers
import datasets
from datasets import load_dataset

Alabama_ds = load_dataset("50States10K/50States10K.py", name="Alabama",split="train")
Alaska_ds = load_dataset("50States10K/50States10K.py", name="Alaska",split="train")
Arizona_ds = load_dataset("50States10K/50States10K.py", name="Arizona",split="train")
Arkansas_ds = load_dataset("50States10K/50States10K.py", name="Arkansas",split="train")
California_ds = load_dataset("50States10K/50States10K.py", name="California",split="train")
Colorado_ds = load_dataset("50States10K/50States10K.py", name="Colorado",split="train")
Connecticut_ds = load_dataset("50States10K/50States10K.py", name="Connecticut",split="train")
Delaware_ds = load_dataset("50States10K/50States10K.py", name="Delaware",split="train")
Florida_ds = load_dataset("50States10K/50States10K.py", name="Florida",split="train", download_mode="force_redownload")
Georgia_ds = load_dataset("50States10K/50States10K.py", name="Georgia",split="train")
Hawaii_ds = load_dataset("50States10K/50States10K.py", name="Hawaii",split="train")
Idaho_ds = load_dataset("50States10K/50States10K.py", name="Idaho",split="train")
Illinois_ds = load_dataset("50States10K/50States10K.py", name="Illinois",split="train")
Indiana_ds = load_dataset("50States10K/50States10K.py", name="Indiana",split="train")
Iowa_ds = load_dataset("50States10K/50States10K.py", name="Iowa",split="train")
Kansas_ds = load_dataset("50States10K/50States10K.py", name="Kansas",split="train")
Kentucky_ds = load_dataset("50States10K/50States10K.py", name="Kentucky",split="train")
Louisiana_ds = load_dataset("50States10K/50States10K.py", name="Louisiana",split="train")
Maine_ds = load_dataset("50States10K/50States10K.py", name="Maine",split="train")
Maryland_ds = load_dataset("50States10K/50States10K.py", name="Maryland",split="train")
Massachusetts_ds = load_dataset("50States10K/50States10K.py", name="Massachusetts",split="train")
Michigan_ds = load_dataset("50States10K/50States10K.py", name="Michigan",split="train")
Minnesota_ds = load_dataset("50States10K/50States10K.py", name="Minnesota",split="train")
Mississippi_ds = load_dataset("50States10K/50States10K.py", name="Mississippi",split="train")
Missouri_ds = load_dataset("50States10K/50States10K.py", name="Missouri",split="train")
Montana_ds = load_dataset("50States10K/50States10K.py", name="Montana",split="train")
Nebraska_ds = load_dataset("50States10K/50States10K.py", name="Nebraska",split="train")
Nevada_ds = load_dataset("50States10K/50States10K.py", name="Nevada",split="train")
New_Hampshire_ds = load_dataset("50States10K/50States10K.py", name="New Hampshire",split="train")
New_Jersey_ds = load_dataset("50States10K/50States10K.py", name="New Jersey",split="train")
New_Mexico_ds = load_dataset("50States10K/50States10K.py", name="New Mexico",split="train")
New_York_ds = load_dataset("50States10K/50States10K.py", name="New York",split="train")
North_Carolina_ds = load_dataset("50States10K/50States10K.py", name="North Carolina",split="train")
North_Dakota_ds = load_dataset("50States10K/50States10K.py", name="North Dakota",split="train")
Ohio_ds = load_dataset("50States10K/50States10K.py", name="Ohio",split="train")
Oklahoma_ds = load_dataset("50States10K/50States10K.py", name="Oklahoma",split="train")
Oregon_ds = load_dataset("50States10K/50States10K.py", name="Oregon",split="train")
Pennsylvania_ds = load_dataset("50States10K/50States10K.py", name="Pennsylvania",split="train")
Rhode_Island_ds = load_dataset("50States10K/50States10K.py", name="Rhode Island",split="train")
South_Carolina_ds = load_dataset("50States10K/50States10K.py", name="South Carolina",split="train")
South_Dakota_ds = load_dataset("50States10K/50States10K.py", name="South Dakota",split="train")
Tennessee_ds = load_dataset("50States10K/50States10K.py", name="Tennessee",split="train")
Texas_ds = load_dataset("50States10K/50States10K.py", name="Texas",split="train")
Utah_ds = load_dataset("50States10K/50States10K.py", name="Utah",split="train")
Vermont_ds = load_dataset("50States10K/50States10K.py", name="Vermont",split="train")
Virginia_ds = load_dataset("50States10K/50States10K.py", name="Virginia",split="train")
Washington_ds = load_dataset("50States10K/50States10K.py", name="Washington",split="train")
West_Virginia_ds = load_dataset("50States10K/50States10K.py", name="West Virginia",split="train")
Wisconsin_ds = load_dataset("50States10K/50States10K.py", name="Wisconsin",split="train")
Wyoming_ds = load_dataset("50States10K/50States10K.py", name="Wyoming",split="train")

# %% [markdown]
# ## Mix and Shuffle

# %%
from datasets import concatenate_datasets

train_ds = concatenate_datasets([Alabama_ds,Alaska_ds,Arizona_ds,Arkansas_ds,California_ds,Colorado_ds,Connecticut_ds,Delaware_ds,Florida_ds,
                                 Georgia_ds,Hawaii_ds,Idaho_ds,Illinois_ds,Indiana_ds,Iowa_ds,Kansas_ds,Kentucky_ds,Louisiana_ds,Maine_ds,
                                 Maryland_ds,Massachusetts_ds,Michigan_ds,Minnesota_ds,Mississippi_ds,Missouri_ds,Montana_ds,Nebraska_ds,Nevada_ds,
                                 New Hampshire_ds,New Jersey_ds,New Mexico_ds,New York_ds,North Carolina_ds,North Dakota_ds,Ohio_ds,Oklahoma_ds,
                                 Oregon_ds,Pennsylvania_ds,Rhode Island_ds,South Carolina_ds,South Dakota_ds,Tennessee_ds,Texas_ds,Utah_ds,
                                 Vermont_ds,Virginia_ds,Washington_ds,West Virginia_ds,Wisconsin_ds,Wyoming_ds])

# %%
train_ds = train_ds.shuffle(seed=42)

# %% [markdown]
# ## Training

# %%
# !pip install transformers
from transformers import ViTImageProcessor, ViTModel
from PIL import Image
import requests

image_path = "./pinetree.jpg"
image = Image.open(image_path)


processor = ViTImageProcessor.from_pretrained('google/vit-base-patch16-224-in21k')
model = ViTModel.from_pretrained('google/vit-base-patch16-224-in21k')

inputs = processor(images=image, return_tensors="pt")
outputs = model(**inputs)
last_hidden_states = outputs.last_hidden_state
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
last_hidden_states.shape
# Out:
# torch.Size([1, 197, 768])

# %%
# !pip install lightning
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 57.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 kB 41.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 48.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 17.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.0/719.0 kB 61.9 MB/s eta 0:00:00
# ...

# %%
import os
from torch import optim, nn, utils, Tensor
from torchvision.datasets import MNIST
from torchvision.transforms import ToTensor
import lightning
import lightning.pytorch as pl

# %%
# define any number of nn.Modules (or use your current ones)
# output [1, 197, 768]
transformer = model
classifier = nn.Sequential(
    nn.Linear(605184, #4 * 197 * 768 input 
              18912),# input/32
    nn.ReLU(), 
    nn.Linear(18912, 591),
    nn.ReLU(),
    nn.Linear(591, 50),
    nn.SoftMax()
)

# define the LightningModule
class LitViTClassifier(pl.LightningModule):
    def __init__(self, transformer, classifier):
        super().__init__()
        self.transformer = transformer
        self.classifier = classifier
        self.loss = nn.CrossEntropy()


    def training_step(self, batch, batch_idx):
        # training_step defines the train loop.
        # it is independent of forward
        x, y = batch
        x = x.view(x.size(0), -1)
        z1 = self.transformer(x[0])
        z2 = self.transformer(x[1])
        z3 = self.transforrmer(x[2])
        z4 = self.transformert(x[3])
        z5 = self.torchcat((z1, z2, z3, z4), axis=1)

        x_hat = self.classifier(z5)


        # Logging to TensorBoard (if installed) by default
        loss = self.log("train_loss", self.loss(x_hat, batch_idx))
        return loss

    def configure_optimizers(self):
        optimizer = optim.Adam(self.parameters(), lr=1e-3)
        return optimizer


# init the autoencoder
autoencoder = LitViTClassifier(transformer, classifier)
